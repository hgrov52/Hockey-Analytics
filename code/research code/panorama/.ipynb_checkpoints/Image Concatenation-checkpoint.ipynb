# %%
import numpy as np
imA = np.zeros((4,4))
imB = np.zeros((4,4))

imA[:,:]=2
print('imA:\n',imA,'\n')

imB[:,:]=3
print('imB:\n',imB,'\n')

avgA = (300,300)
avgB = (299,301)
shift_x = avgA[0]-avgB[0]
shift_y = avgA[1]-avgB[1]

print(shift_x,shift_y)

result = np.zeros((imA.shape[1]+abs(avgA[1]-avgB[1]),imA.shape[0]+abs(avgA[0]-avgB[0])))
result[:,:]=-np.inf

# np.where(result[#:#,#:#]==-np.inf,im#,result[#:#,#:#])

#     # if B is directly left
#     else:
        
# if(avgB[0]>avgA[0]:
#     # if B is right and up
#     if(avgB[1]<avgA[1]):
        
#     # if B is right and down
#     if(avgB[1]>avgA[1]):
                
#     # if B is directly right
#     else:
   
# else:
#    # if B is  directly up
#     if(avgB[1]<avgA[1]):
        
#     # if B is directly down
#     if(avgB[1]>avgA[1]):
                
#     # if B is the same as A
#     else:


if(shift_x>0):
    # if B is left and up
    if(shift_y>0):
        print('result:\n',result)
        result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)]=       \
        np.where(result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)]==-np.inf,   \
        imA,result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)])
        print('result:\n',result)
        result[0:imB.shape[1],0:imB.shape[0],]=np.where(result[0:imB.shape[1],0:imB.shape[0]]==-np.inf,  \
        imB,result[0:imB.shape[1],0:imB.shape[0]])
        print('result:\n',result)
        
    # if B is left and (down or even)
    else:
        shift_y=abs(shift_y)
        
        
        result[0:imA.shape[1],shift_x:(imA.shape[0]+shift_x)]=       \
        np.where(result[0:imA.shape[1],shift_x:(imA.shape[0]+shift_x)]==-np.inf,   \
        imA,result[0:imA.shape[1],shift_x:(imA.shape[0]+shift_x)])
        print('result:\n',result)
        result[shift_y:(imB.shape[1]+shift_y),0:imB.shape[0]]=      \
        np.where(result[shift_y:(imB.shape[1]+shift_y),0:imB.shape[0]]==-np.inf,       \
        imB,result[shift_y:(imB.shape[1]+shift_y),0:imB.shape[0]])
        print('result:\n',result)
# Out:
# imA:
#  [[2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]]
#
# imB:
#  [[3. 3. 3. 3.]
#  [3. 3. 3. 3.]
#  [3. 3. 3. 3.]
#  [3. 3. 3. 3.]]
#
# 1 -1
# result:
#  [[-inf   2.   2.   2.   2.]
#  [-inf   2.   2.   2.   2.]
#  [-inf   2.   2.   2.   2.]
#  [-inf   2.   2.   2.   2.]
#  [-inf -inf -inf -inf -inf]]
# result:
#  [[-inf   2.   2.   2.   2.]
#  [  3.   2.   2.   2.   2.]
#  [  3.   2.   2.   2.   2.]
#  [  3.   2.   2.   2.   2.]
#  [  3.   3.   3.   3. -inf]]

# %%
import numpy as np
imA = np.zeros((4,4))
imB = np.zeros((4,4))

imA[:,:]=2
print('imA:\n',imA,'\n')

imB[:,:]=3
print('imB:\n',imB,'\n')

avgA = (300,300)
avgB = (300,300)
shift_x = avgA[0]-avgB[0]
shift_y = avgA[1]-avgB[1]

print(shift_x,shift_y)

result = np.zeros((imA.shape[1]+abs(avgA[1]-avgB[1]),imA.shape[0]+abs(avgA[0]-avgB[0])))
result[:,:]=-np.inf

right = 0
if(shift_x<0):
    right = abs(shift_x)
    shift_x = 0
down = 0
if(shift_y<0):
    down = abs(shift_y)
    shift_y = 0
print('result:\n',result)
result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)]= \
np.where(result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)]==-np.inf, \
imA,result[shift_y:(imA.shape[1]+shift_y),shift_x:(imA.shape[0]+shift_x)])
result[down:(imB.shape[1]+down),right:(imB.shape[0]+right)]= \
np.where(result[down:(imB.shape[1]+down),right:(imB.shape[0]+right)]==-np.inf, \
imB,result[down:(imB.shape[1]+down),right:(imB.shape[0]+right)])
print('result:\n',result)
# Out:
# imA:
#  [[2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]]
#
# imB:
#  [[3. 3. 3. 3.]
#  [3. 3. 3. 3.]
#  [3. 3. 3. 3.]
#  [3. 3. 3. 3.]]
#
# 0 0
# 0 0
# result:
#  [[-inf -inf -inf -inf]
#  [-inf -inf -inf -inf]
#  [-inf -inf -inf -inf]
#  [-inf -inf -inf -inf]]
# result:
#  [[2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]
#  [2. 2. 2. 2.]]
